# %% [markdown]
# <a href="https://colab.research.google.com/github/Itallo-queiroz/Itallo-queiroz/blob/main/Aula_0_de_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'Itallo'
# Out:
# 'Itallo'

# %%
'Verde'
# Out:
# 'Verde'

# %%
print('Boas vindas a aula de Python')
# Out:
# Boas vindas a aula de Python

# %%
nome = 'Itallo'

# %%
nome
# Out:
# 'Itallo'

# %%
cor_favorita = 'Verde, Branco'

# %%
cor_favorita
# Out:
# 'Verde, Branco'

# %%
print(nome, cor_favorita)
# Out:
# Itallo Verde, Branco

# %%
saldo = 5000

# %%
saldo
# Out:
# 5000

# %%
saldo = saldo + 500

# %%
saldo
# Out:
# 5500

# %%
print('Saldo na sua conta: R$', saldo)
# Out:
# Saldo na sua conta: R$ 5500

# %%
idade = 18

# se idade for maior que 18
if idade >= 18:
  # pode dirigir
  print("Pode dirigir")
# senão
else:
# não pode dirigir
  print("Não pode dirigir")
# Out:
# Pode dirigir
